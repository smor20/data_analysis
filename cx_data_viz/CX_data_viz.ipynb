# %%
import pandas as pd
import numpy as np
import xlwings as xw
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# If you want to set font sizes globally for all your plots, you can use mpl.rcParams. Here’s an example of how to set font sizes for titles and labels globally:
import matplotlib.pyplot as plt
import matplotlib as mpl

# Set global font sizes
mpl.rcParams['axes.titlesize'] = 'small'   # Font size for axes title
mpl.rcParams['axes.labelsize'] = 'small'  # Font size for x and y labels

# # Create your plot
# fig = plt.figure()
# plt.plot(data)
# fig.suptitle('Test Title')  # Figure title font size will be 'large' (from rcParams)
# plt.xlabel('X Label')       # x-label font size will be 'medium' (from rcParams)
# plt.ylabel('Y Label')       # y-label font size will be 'medium' (from rcParams)
# fig.savefig('test.jpg')

# # to set values for indivdual chart
# fig = plt.figure()
# plt.plot(data)
# fig.suptitle('Test Title', fontsize=20)  # Set font size for the figure title
# plt.xlabel('X Label', fontsize=18)       # Set font size for x-label
# plt.ylabel('Y Label', fontsize=16)       # Set font size for y-label
# fig.savefig('test.jpg')

# %%
file_name='data_viz.xlsx'
batsman=pd.read_excel(file_name,sheet_name='d23_sharma-kohli')
batter=pd.read_excel(file_name,sheet_name='d23_batter')
batter_record=pd.read_excel(file_name,sheet_name='d23_batsman_season_record')
vk=pd.read_excel(file_name,sheet_name='d23_vk')
gayle175=pd.read_excel(file_name,sheet_name='d23_gayle-175')
delivery=pd.read_excel(file_name,sheet_name='ipl_ball_by_ball')

tips=sns.load_dataset('tips')

arr=np.load('d23_big-array.npy')
iris=pd.read_excel(file_name, sheet_name='iris')
# batsman

# %% [markdown]
# ## L-23 Matplotlib

# %% [markdown]
# ### 2D Line plot

# %% [markdown]
# **2D Line Plot**
# used for
# - Bivariate Analysis-- i.e works on 2 cols.
# - used with categorical-numerical data; numerical-numerical data.
#     cat data is place on x-axis & numerical data on y-axis
# - categorical -> numerical and numerical -> numerical
# - Use case - Time series data

# %%
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.ylim(45000, 75000)
plt.show()

# %%
price = [48000,54000,57000,49000,47000,45000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.show() # makes the graph to appear on screen(in ide this is not required though). in text editors like pycharm, or in flask plt.show() is must to display the graph.

# %%
price = [48000,54000,57000,49000,47000,45000,4500000]
year = [2015,2016,2017,2018,2019,2020,2021]

plt.plot(year,price)
# xlim and ylim are used when there are outlier in the graph generally in y-axis
plt.xlim(2015,2020) # useful when there is spike in the value and graph change due to that.
plt.ylim(40000,75000) # will limit the y-aixs between 40K and 75K
# Out:
# (2015.0, 2020.0)

# %%
batsman.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(batsman['index'], batsman['V Kohli'])
plt.plot(batsman['index'], batsman['RG Sharma'])
plt.title('kohli vs rs')
plt.xlabel('year')
plt.ylabel('runs')
# Out:
# Text(0, 0.5, 'runs')

# %%
## colors(hex) and line(width and style) and marker(size)

plt.plot(batsman['index'],batsman['V Kohli'], color='green', linestyle='dotted', linewidth='0.5', marker='D', markersize=2, label='Virat') # hex code can also be provided.
plt.plot(batsman['index'],batsman['RG Sharma'], color='blue', linestyle='dashed', marker='.', markersize=10, label='Rohit')
# linestyle-->'sold','dashed','dotted', 'dashdot'
plt.title('Kholi vs R Sharma ipl comparison')
plt.xlabel('ipl season')
plt.ylabel('runs scored')

plt.legend(loc='best') # best is default
plt.grid()

# %% [markdown]
# ### scatter plot

# %% [markdown]
# **Scatter plot** is used for
# - bivariate analysis -> numerical VS numerical
# - use case -> to find corelation b/w 2 variables.
#
# 2D plot is a special case of scatter plot--when pts of scatter plot are joined it become 2D plot.

# %%
x=np.linspace(-10,10,50) #genrates 50 equidistant pts b/w -10,10.
y=10*x+3+np.random.randint(0,300,50)

plt.scatter(x,y)

# %%
batter.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.scatter(batter['avg'], batter['strike_rate'], marker='+') # every dot/+ rep 1 batsman.

plt.title('avg and SR analysis of top 50 batsmans')
plt.xlabel('avg')
plt.ylabel('SR')
# Out:
# Text(0, 0.5, 'SR')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'],tips['tip'], s=tips['size']*10)  #mul with 10 done to accentuate the diff. b/w dots.

# plt.plot(tips['total_bill'],tips['tip'],'o') 
# scatter can be plotted using plt.plot by passing 'o' in it.
# benefits: faster, good with larger data || -ve -> customisation not available like (s=tiips['size'])

# %% [markdown]
# ### Bar chart

# %% [markdown]
# **Bar chart** used for-
# - Bivariate Analysis -(Cat vs Num)--> x-axis:Categorical column || y-axis: aggregated data based categories of cat-col.
# - Use case - Aggregate analysis of groups

# %%
colors=['red', 'blue', 'green','yellow','pink']
childern=[10,20,40,10,30]

plt.bar(colors, childern, color='pink') #use plt.barh() to get horizontal bar chart.
# Out:
# <BarContainer object of 5 artists>

# %%
colors=['redredredred', 'blue redredred', 'green redredred','yellow redredred','pink redredred']
childern=[10,20,40,10,30]

plt.bar(colors, childern, color='pink') #use plt.barh() to get horizontal bar chart.
plt.xticks(rotation=70)

# plt.barh(colors, childern, color='pink')
# plt.yticks(rotation=70)
plt.show()

# %%
batter_record.head()
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
# plt.bar(batter_record['batsman'], batter_record[2015])
plt.bar(np.arange(batter_record.shape[0])-0.2, batter_record[2015], width=0.2)
plt.bar(np.arange(batter_record.shape[0]), batter_record[2016], width=0.2)
plt.bar(np.arange(batter_record.shape[0])+0.2, batter_record[2017], width=0.2)

plt.xticks(np.arange(batter_record.shape[0]), batter_record['batsman'])
plt.show()

# %%
## stacked bar chart
plt.bar(batter_record['batsman'], batter_record[2015], label='2015')
plt.bar(batter_record['batsman'], batter_record[2016], bottom=batter_record[2015], label='2016')
plt.bar(batter_record['batsman'], batter_record[2017], bottom=batter_record[2015]+batter_record[2016], label='2017')

plt.legend()
plt.show()

# %% [markdown]
# ### Histogram

# %% [markdown]
# It is like bar chart but for numerical column(bar chart is used for categorical column.)
# - univeriate analysis-- used for numerical columns.
# - use case-- frequency count

# %%
data = [32,45,56,10,15,27,61]

# plt.hist(data,bins=[10,25,40,55,70])
plt.hist(data)
plt.show()

# %%
vk.head()   #vk has the runs scored by kohli in each match.
plt.hist(vk['batsman_runs'])
plt.show()

# %%
arr.shape
# plt.hist(arr) # due to more nums in bin (30-40) the bin of (10-20) looks empty which is not true.
plt.hist(arr, bins=[10,20,30,40,50,60,70], log=True)    # now y-axis is a logrithmic scale.
# Out:
# (array([   23.,   200., 10000.,   400.,  1234.,    92.]),
#  array([10., 20., 30., 40., 50., 60., 70.]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# ### pie chart

# %% [markdown]
# - Univariate/Bivariate Analysis
# - Categorical vs numerical
# - Use case - To find contibution on a standard scale

# %%
data=[20,45,100,20,49]
subjects = ['eng','science','maths','sst','hindi']
plt.pie(data, labels=subjects)

# plt.legend()
plt.show()

# %%
gayle175
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
gayle175.head()
plt.pie(gayle175['batsman_runs'], labels=gayle175['batsman'], autopct='%0.1f%%', explode=[0.1,0,0,0,0,0.2],shadow=True)
## explode--is used to take out the pie of a category.
## colors can be added by color=[name 6 clrs for these 6 batsmans]

# plt.show()
plt.savefig('gayle.png')

# %% [markdown]
# ### styles

# %%
plt.style.available

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## L24-matplotlib

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 96    97            5.7           2.9            4.2           1.3
# 0      1            5.1           3.5            1.4           0.2
# 143  144            6.8           3.2            5.9           2.3
# 112  113            6.8           3.0            5.5           2.1
# 79    80            5.7           2.6            3.5           1.0
#
#              Species
# 96   Iris-versicolor
# 0        Iris-setosa
# 143   Iris-virginica
# 112   Iris-virginica
# 79   Iris-versicolor

# %%
iris['species_code']=iris.apply(lambda row:0 if row['Species']=='Iris-setosa' else
                                                1 if row['Species']=='Iris-versicolor' else
                                                2 if row['Species']=='Iris-virginica' else
                                                row['Species'], axis=1)

# %%
plt.figure(figsize=(8,4))

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['species_code'], cmap='jet', alpha=0.3)
# c=iris['species_code']--> will make the color coded dots on the chart.
# cmap--> there are various color themes in matplotlibs like viridis,cividis,plasma,inferno,magma etc
# lesser value of alpha will make the colors faded-like.

plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()
plt.legend()    #?-how to add legends for color coding of points

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
## Annotation
plt.figure(figsize=(4,2))

l1=[1,2]
l2=[3,4]
plt.scatter(l1,l2)
plt.text(1,3,'P1')
plt.text(2,4,'P2', fontdict={'size':8,'color':'brown'})

plt.show()

# %%
plt.figure(figsize=(18,10))
sample_batters=batter.head(100).sample(25, random_state=5)
plt.scatter(sample_batters['avg'], sample_batters['strike_rate'], s=sample_batters['runs'])

for i in range(sample_batters.shape[0]):
    plt.text(sample_batters['avg'].values[i],sample_batters['strike_rate'].values[i],sample_batters['batter'].values[i])

plt.axhline(130, color='red')
plt.axvline(30, color='green')

plt.show()

# %%
# fig, ax= plt.subplots(figsize=(15,7))
fig,ax = plt.subplots(figsize=(15,6))

ax.scatter(sample_batters['avg'], sample_batters['strike_rate'],c='red', marker='+')
ax.set_title('Avg & SR comparison')
ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')

# fig.show()
# Out:
# Text(0, 0.5, 'Strike Rate')

# %% [markdown]
# ### 3D scatter and line plot

# %%
fig,ax=plt.subplots(nrows=2, ncols=1, sharex=True)
# sharex=True >data pts will be shown on the last graph only.
ax[0].scatter(batter['avg'],batter['strike_rate'], color='red')
ax[1].scatter(batter['avg'],batter['runs'], color='green', marker='+')

# %%
fig=plt.figure()

ax1=fig.add_subplot(2,2,1)
ax1.scatter(batter['avg'],batter['strike_rate'], color='red')

ax2=fig.add_subplot(2,2,2)
ax2.hist(batter['avg'])

# ax3=fig.add_subplot(2,2,3)
# ax3.hist(batter['strike_rate'])

## NOT A GOOD WAY TO DRAW SUBPLOTS.
plt.show()

# %%
fig=plt.figure(figsize=(10,4))

ax=plt.subplot(projection='3d')
ax.scatter3D(batter['runs'],batter['avg'], batter['strike_rate'])

ax.set_title('IPL Batsman Analysis')
ax.set_xlabel('Runs')
# Out:
# Text(0.5, 0, 'Runs')

# %%
fig=plt.figure(figsize=(10,4))
ax=plt.subplot(projection='3d')
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]

ax.scatter3D(x,y,z, s=[20,20,20,20])
ax.plot3D(x,y,z)

# %% [markdown]
# ### 3D surface plot

# %%
x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)
xx, yy =np.meshgrid(x,y)
z=xx**2+yy**2
# z=np.sin(xx)+np.cos(yy)

# %%
fig=plt.figure(figsize=(12,6))

ax=plt.subplot(projection='3d')

p=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

plt.show()

# %%
## contour plot-- It projects the 3D grph in 2D

fig=plt.figure(figsize=(12,6))

ax=plt.subplot()
p=ax.contour(xx,yy,z,cmap='viridis')

fig.colorbar(p)
plt.show()

# %%
## contourf plot-- It projects the 3D grph in 2D but colors are filled.

fig=plt.figure(figsize=(12,6))

ax=plt.subplot()
p=ax.contourf(xx,yy,z,cmap='viridis')

fig.colorbar(p)
plt.show()

# %% [markdown]
# ### Heatmap

# %%
delivery.head()
temp_df=delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run'].isin([6]))]

# %%
grid=pd.pivot_table(temp_df, index='overs', columns='ballnumber', values='batsman_run', aggfunc='count')

# %%
plt.figure(figsize=(12,6))
plt.imshow(grid)

plt.xticks(np.arange(0,6), list(range(1,7)))
plt.yticks(delivery['overs'].unique(), list(range(1,21)))
plt.colorbar()

# %% [markdown]
# ### Pandas Plot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.plot(kind='scatter',x='total_bill',y='tip', title='Cost Analysis', xlabel='Total Bill', figsize=(8,4), s='size',c='sex', cmap='viridis')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='Total Bill', ylabel='tip'>

# %%
tips.pivot_table(index='day', columns=['sex'],  aggfunc={'total_bill':'mean','tip':'mean'}).plot(kind='line')

# tips.pivot_table(index='day',columns=['sex','smoker'],values='total_bill',aggfunc='mean')
# Out:
# <Axes: xlabel='day'>

# %%
# dataset = 'https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv'

stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
# stocks.plot(kind='line', x='Date')
# stocks[['Date','MSFT','FB']].plot(kind='line', x='Date')
# stocks.plot(kind='line', x='Date')
stocks.plot(kind='line', x='Date', subplots=True) # will give 3 seprate chart arranged vertically one above another.
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
tips.groupby('sex')['total_bill'].mean().plot(kind='bar',x='sex', y ='total_bill')
# Out:
# <Axes: xlabel='sex'>

# %%
print(batter_record.head())
# batter_record[2015].plot(kind='bar')
batter_record.plot(kind='bar', stacked=True)
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308
# <Axes: >

# %%
# pie -> single and multiple
df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120,90,35,45,12,10],
        'match2':[0,1,123,130,34,45],
        'match3':[50,24,145,45,10,90]
    }
)

df.head()
# Out:
#   batsman  match1  match2  match3
# 0  Dhawan     120       0      50
# 1   Rohit      90       1      24
# 2   Kohli      35     123     145
# 3     SKY      45     130      45
# 4  Pandya      12      34      10

# %%
# df['match1'].plot(kind='pie',labels=df['batsman'].values,autopct='%0.1f%%')

# multiple pie charts
df[['match1','match2','match3']].plot(kind='pie',subplots=True,figsize=(15,8))
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)
